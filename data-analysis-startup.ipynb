# %% [markdown]
# # DATA ANALYSIS START-UP EXPANSION

# %% [markdown]
# ### Imprting libraries

# %%
import numpy as np
import pandas as pd

# %%
startups = pd.read_csv("startup-data.csv")
startups
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#     Marketing Spend  Revenue
# 0            $2,601  $48,610
# 1            $2,727  $45,689
# 2            $2,768  $49,554
# ...

# %%
startups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    int64
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    object
#  6   Revenue          150 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 8.3+ KB

# %%
startups[['Marketing Spend', 'Revenue']].describe()
# Out:
#        Marketing Spend  Revenue
# count              150      150
# unique             142      150
# top             $2,854  $48,610
# freq                 2        1

# %% [markdown]
#  ### Preprocessing Data

# %%
startups['City'].unique()
# Out:
# array(['Peoria', 'Midland', 'Spokane', 'Denton', 'Overland Park',
#        'Yonkers', 'Birmingham', 'Antioch', 'Worcester', 'Rochester',
#        'Rialto', 'Santa Maria', 'Las Cruces', 'Jackson', 'Hillsboro',
#        'Temecula', 'Tallahassee', 'Fontana', 'Kent', 'Broken Arrow',
#        'Concord', 'Modesto', 'Montgomery', 'Burbank', 'Elk Grove',
#        'Port St. Lucie', 'Elizabeth', 'Salt Lake City', 'Waco', 'Edison',
#        'Boulder', 'Grand Rapids', 'Tyler', 'Charleston', 'Huntsville',
#        'Pearland', 'Inglewood', 'Oxnard', 'Miramar', 'Cape Coral',
#        'Syracuse', 'Newport News', 'Lewisville', 'Carrollton',
#        'San Bernardino', 'Pasadena', 'Roseville', 'Murrieta',
#        'San Angelo', 'Olathe', 'Akron', 'Fullerton', 'Manchester',
#        'Everett', 'West Covina', 'Thornton', 'Hampton', 'Waterbury',
#        'Ventura', 'Davenport', 'Columbia', 'Simi Valley', 'Richmond',
#        'Little Rock', 'El Cajon', 'Santa Clara', 'Oceanside', 'Davie',
# ...

# %%
startups['City'].value_counts()
# Out:
# City
# Rochester        2
# Killeen          1
# Wichita Falls    1
# Naperville       1
# Clovis           1
#                 ..
# Akron            1
# Fullerton        1
# Manchester       1
# Everett          1
# Thousand Oaks    1
# Name: count, Length: 149, dtype: int64

# %% [markdown]
# why I have Rochester two time ?

# %%
startups['State'].value_counts()
# Out:
# State
# California        40
# Texas             17
# Florida           12
# Washington         7
# Colorado           5
# Illinois           5
# Georgia            4
# Alabama            4
# Connecticut        4
# New Jersey         4
# Arizona            3
# Tennessee          3
# Iowa               3
# Michigan           3
# South Carolina     3
# Utah               3
# Massachusetts      3
# Kansas             3
# New York           3
# Louisiana          2
# North Carolina     2
# Ohio               2
# Virginia           2
# Oregon             2
# Mississippi        1
# New Mexico         1
# Arkansas           1
# New Hampshire      1
# Oklahoma           1
# Montana            1
# Indiana            1
# South Dakota       1
# Minnesota          1
# Wisconsin          1
# Rhode Island       1
# Name: count, dtype: int64

# %%
startups['Sales Region'].unique()
# Out:
# array(['Region 2', 'Region 1'], dtype=object)

# %%
startups['Sales Region'].value_counts()
# Out:
# Sales Region
# Region 2    86
# Region 1    64
# Name: count, dtype: int64

# %%
startups['New Expansion'].unique()
# Out:
# array(['Old', 'New'], dtype=object)

# %%
startups['New Expansion'].value_counts()
# Out:
# New Expansion
# Old    140
# New     10
# Name: count, dtype: int64

# %%
startups.isna().sum()
# Out:
# Store ID           0
# City               0
# State              0
# Sales Region       0
# New Expansion      0
# Marketing Spend    0
# Revenue            0
# dtype: int64

# %%
startups.duplicated().sum()
# Out:
# 0

# %% [markdown]
# that s good that s mean that  there is no duplicated lines

# %%
startups['Marketing Spend'] = startups['Marketing Spend'].replace({'\$': '', ',': ''}, regex=True).astype(int)
startups['Revenue'] = startups['Revenue'].replace({'\$': '', ',': ''}, regex=True).astype(int)

# Vérifier le résultat
print(startups[['Marketing Spend', 'Revenue']])
# Out:
#      Marketing Spend  Revenue
# 0               2601    48610
# 1               2727    45689
# 2               2768    49554
# 3               2759    38284
# 4               2869    59887
# ..               ...      ...
# 145             2251    34603
# 146             3675    63148
# 147             2648    43377
# 148             2994    22457
# 149             2431    40141
#
# [150 rows x 2 columns]

# %% [markdown]
#  ### Exploring and Analysing Data

# %% [markdown]
# Brainstorming -- trying to ask the main quetion --> Analyze the relationship between revenue and geographic data and the spend.

# %%
startups.sample(10)
# Out:
#      Store ID              City        State Sales Region New Expansion  \
# 102       103           Visalia   California     Region 2           Old
# 63         64       Little Rock     Arkansas     Region 2           Old
# 20         21           Concord   California     Region 2           Old
# 17         18           Fontana   California     Region 2           Old
# 41         42      Newport News     Virginia     Region 1           Old
# 110       111          Stamford  Connecticut     Region 1           Old
# 118       119  Huntington Beach   California     Region 2           Old
# 122       123        Bridgeport  Connecticut     Region 1           Old
# 51         52         Fullerton   California     Region 2           Old
# 0           1            Peoria      Arizona     Region 2           Old
#
#      Marketing Spend  Revenue
# 102             2104    45632
# 63              2440    68828
# 20              2521    38178
# 17              3085    63027
# ...

# %% [markdown]
# #### Having new columns to more understand the dataset !!!

# %%
startups['ROI']  = round(( startups['Revenue'] / startups['Marketing Spend'])*100 , 2 )

# %%
startups.sample(10)
# Out:
#      Store ID           City         State Sales Region New Expansion  \
# 39         40     Cape Coral       Florida     Region 1           Old
# 67         68          Davie       Florida     Region 1           Old
# 36         37      Inglewood    California     Region 2           Old
# 117       118       Bellevue    Washington     Region 2           Old
# 149       150  Thousand Oaks    California     Region 2           New
# 41         42   Newport News      Virginia     Region 1           Old
# 10         11         Rialto    California     Region 2           Old
# 79         80     Costa Mesa    California     Region 2           Old
# 37         38         Oxnard    California     Region 2           Old
# 108       109    Sioux Falls  South Dakota     Region 1           Old
#
#      Marketing Spend  Revenue      ROI
# 39              2886    52250  1810.46
# 67              3177    45418  1429.59
# 36              2904    20455   704.37
# ...

# %%
startups['Profit']  = startups['Revenue'] - startups['Marketing Spend']

# %%
startups.sample(10)
# Out:
#      Store ID           City        State Sales Region New Expansion  \
# 109       110  Grand Prairie        Texas     Region 2           Old
# 126       127   Cedar Rapids         Iowa     Region 1           Old
# 54         55    West Covina   California     Region 2           Old
# 56         57        Hampton     Virginia     Region 1           Old
# 77         78      New Haven  Connecticut     Region 1           Old
# 55         56       Thornton     Colorado     Region 2           Old
# 63         64    Little Rock     Arkansas     Region 2           Old
# 136       137         Warren     Michigan     Region 1           Old
# 94         95    Gainesville      Florida     Region 1           Old
# 45         46       Pasadena   California     Region 2           Old
#
#      Marketing Spend  Revenue      ROI  Profit
# 109             3131    50895  1625.52   47764
# 126             2553    52072  2039.64   49519
# 54              2939    21824   742.57   18885
# ...

# %%
startups['ROM']  = round((startups['Profit'] / startups['Marketing Spend'])*100 , 2 )

# %%
startups.sample(10)
# Out:
#      Store ID              City         State Sales Region New Expansion  \
# 47         48          Murrieta    California     Region 2           Old
# 118       119  Huntington Beach    California     Region 2           Old
# 0           1            Peoria       Arizona     Region 2           Old
# 134       135        Santa Rosa    California     Region 2           Old
# 108       109       Sioux Falls  South Dakota     Region 1           Old
# 18         19              Kent    Washington     Region 2           Old
# 67         68             Davie       Florida     Region 1           Old
# 112       113         Knoxville     Tennessee     Region 2           Old
# 101       102     Coral Springs       Florida     Region 1           Old
# 129       130     Pompano Beach       Florida     Region 1           Old
#
#      Marketing Spend  Revenue      ROI  Profit      ROM
# 47              2344    16372   698.46   14028   598.46
# ...

# %%
startups.to_csv('startups-expansion-modified.csv')
